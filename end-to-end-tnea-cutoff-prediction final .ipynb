# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# %%
#importing 2017-2020 data
df = pd.read_csv("data/2017-2020.csv",low_memory=False, parse_dates=["Year"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          240 non-null    datetime64[ns]
#  1   College Code  240 non-null    int64
#  2   College_Name  240 non-null    object
#  3   Branch Code   240 non-null    object
#  4   Branch Name   240 non-null    object
#  5   OC            240 non-null    float64
#  6   BC            227 non-null    float64
#  7   BCM           218 non-null    float64
#  8   MBC           228 non-null    float64
#  9   SC            228 non-null    float64
#  10  SCA           203 non-null    float64
#  11  ST            118 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(3)
# memory usage: 22.6+ KB

# %%
df.isna().sum() #eturns the number of missing values in each column
# Out:
# Year              0
# College Code      0
# College_Name      0
# Branch Code       0
# Branch Name       0
# OC                0
# BC               13
# BCM              22
# MBC              12
# SC               12
# SCA              37
# ST              122
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'College Code', 'College_Name', 'Branch Code', 'Branch Name',
#        'OC', 'BC', 'BCM', 'MBC', 'SC', 'SCA', 'ST'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.scatter(df["Year"][:1000], df["OC"][:1000])

# %%
df.Year[:1000]
# Out:
# 0     2017-01-01
# 1     2017-01-01
# 2     2017-01-01
# 3     2017-01-01
# 4     2017-01-01
#          ...
# 235   2020-01-01
# 236   2020-01-01
# 237   2020-01-01
# 238   2020-01-01
# 239   2020-01-01
# Name: Year, Length: 240, dtype: datetime64[ns]

# %%
df.Year.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.OC.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Year.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.Year[:1000]
# Out:
# 0     2017-01-01
# 1     2017-01-01
# 2     2017-01-01
# 3     2017-01-01
# 4     2017-01-01
#          ...
# 235   2020-01-01
# 236   2020-01-01
# 237   2020-01-01
# 238   2020-01-01
# 239   2020-01-01
# Name: Year, Length: 240, dtype: datetime64[ns]

# %%
df.head()
# Out:
#         Year  College Code                                       College_Name  \
# 0 2017-01-01             1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 1 2017-01-01             1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 2 2017-01-01             1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 3 2017-01-01             1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 4 2017-01-01             1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
#
#   Branch Code                            Branch Name      OC      BC     BCM  \
# 0          AI  Agricultural and Irrigation Engg.(SS)  196.25  195.25  193.25
# 1          BY                   Bio Medical Engg(SS)  198.25  197.50  197.25
# 2          CE                      Civil Engineering  198.50  198.00  197.50
# 3          CM         Computer Science and Engg.(SS)  199.00  198.75  199.00
# 4          CS             Computer Science and Engg.  199.75  199.50  199.50
#
#       MBC      SC     SCA      ST
# 0  194.25  188.75  185.75  175.25
# 1  196.50  193.00  191.75  188.00
# 2  197.50  196.00  193.50  196.00
# 3  197.75  193.50  190.50  193.33
# 4  199.00  197.50  196.25  193.75

# %%
#transpose
df.head().T
# Out:
#                                                               0  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  AI
# Branch Name               Agricultural and Irrigation Engg.(SS)
# OC                                                       196.25
# BC                                                       195.25
# BCM                                                      193.25
# MBC                                                      194.25
# SC                                                       188.75
# SCA                                                      185.75
# ST                                                       175.25
#
#                                                               1  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  BY
# Branch Name                                Bio Medical Engg(SS)
# OC                                                       198.25
# BC                                                        197.5
# BCM                                                      197.25
# MBC                                                       196.5
# SC                                                        193.0
# SCA                                                      191.75
# ST                                                        188.0
#
#                                                               2  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CE
# Branch Name                                   Civil Engineering
# OC                                                        198.5
# BC                                                        198.0
# BCM                                                       197.5
# MBC                                                       197.5
# SC                                                        196.0
# SCA                                                       193.5
# ST                                                        196.0
#
#                                                               3  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CM
# Branch Name                      Computer Science and Engg.(SS)
# OC                                                        199.0
# BC                                                       198.75
# BCM                                                       199.0
# MBC                                                      197.75
# SC                                                        193.5
# SCA                                                       190.5
# ST                                                       193.33
#
#                                                               4
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CS
# Branch Name                          Computer Science and Engg.
# OC                                                       199.75
# BC                                                        199.5
# BCM                                                       199.5
# MBC                                                       199.0
# SC                                                        197.5
# SCA                                                      196.25
# ST                                                       193.75

# %%
df.Year.head(20)
# Out:
# 0    2017-01-01
# 1    2017-01-01
# 2    2017-01-01
# 3    2017-01-01
# 4    2017-01-01
# 5    2017-01-01
# 6    2017-01-01
# 7    2017-01-01
# 8    2017-01-01
# 9    2017-01-01
# 10   2017-01-01
# 11   2017-01-01
# 12   2017-01-01
# 13   2017-01-01
# 14   2017-01-01
# 15   2017-01-01
# 16   2017-01-01
# 17   2017-01-01
# 18   2017-01-01
# 19   2017-01-01
# Name: Year, dtype: datetime64[ns]

# %%
df.sort_values(by=["Year"], inplace=True, ascending=True)
df.Year.head(20)
# Out:
# 0    2017-01-01
# 32   2017-01-01
# 33   2017-01-01
# 34   2017-01-01
# 35   2017-01-01
# 36   2017-01-01
# 37   2017-01-01
# 38   2017-01-01
# 39   2017-01-01
# 40   2017-01-01
# 41   2017-01-01
# 42   2017-01-01
# 43   2017-01-01
# 45   2017-01-01
# 46   2017-01-01
# 47   2017-01-01
# 48   2017-01-01
# 49   2017-01-01
# 50   2017-01-01
# 51   2017-01-01
# Name: Year, dtype: datetime64[ns]

# %%
df_tmp = df.copy()

# %%
df_tmp["tYear"] = df_tmp.Year.dt.year

# %%
df_tmp.head().T
# Out:
#                                                              0   \
# Year                                        2017-01-01 00:00:00
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  AI
# Branch Name               Agricultural and Irrigation Engg.(SS)
# OC                                                       196.25
# BC                                                       195.25
# BCM                                                      193.25
# MBC                                                      194.25
# SC                                                       188.75
# SCA                                                      185.75
# ST                                                       175.25
# tYear                                                      2017
#
#                                                              32  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CM
# Branch Name                      Computer Science and Engg.(SS)
# OC                                                        198.5
# BC                                                       198.33
# BCM                                                       197.5
# MBC                                                       197.0
# SC                                                        192.0
# SCA                                                       186.0
# ST                                                          NaN
# tYear                                                      2017
#
#                                                              33  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CS
# Branch Name                          Computer Science and Engg.
# OC                                                       198.75
# BC                                                        198.5
# BCM                                                       198.0
# MBC                                                      197.75
# SC                                                        195.0
# SCA                                                       197.5
# ST                                                       192.25
# tYear                                                      2017
#
#                                                              34  \
# Year                                        2017-01-01 00:00:00
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EC
# Branch Name                          Electronics and Comm Engg.
# OC                                                       199.25
# BC                                                        199.0
# BCM                                                       198.0
# MBC                                                      198.25
# SC                                                        196.5
# SCA                                                      196.25
# ST                                                       188.25
# tYear                                                      2017
#
#                                                              35
# Year                                        2017-01-01 00:00:00
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EI
# Branch Name                        Electronics and Instru Engg.
# OC                                                       198.25
# BC                                                        198.0
# BCM                                                      197.75
# MBC                                                      197.25
# SC                                                       192.75
# SCA                                                      190.75
# ST                                                        176.5
# tYear                                                      2017

# %%
df_tmp.drop("Year", axis=1, inplace=True)  #Drop specified labels from rows or columns. Remove rows or columns by specifying label names and corresponding axis

# %%
df_tmp.College_Name.value_counts()
# Out:
# UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHENNAI - CEG CAMPUS,SARDAR PATEL ROAD, GUINDY,CHENNAI DIST, PIN - 600025.             36
# University Departments of Anna University, Chennai - CEG Campus, Sardar Patel Road, Guindy, Chennai 600 025                       34
# UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHENNAI - MIT CAMPUS,CHROMPET,,KANCHEEPURAM DIST, PIN - 600044.                        26
# UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHENNAI - ACT CAMPUS,SARDAR PATEL ROAD, GUINDY,CHENNAI DIST, PIN - 600025.             22
# University Departments of Anna University, Chennai - ACT Campus, Sardar Patel Road, Guindy, Chennai 600 025                       22
# Annamalai University Faculty of Engineering and Technology,Annamalai nagar,Cuddalore 608002                                       12
# University Departments of Anna University, Chennai - MIT Campus, Chrompet, Tambaram Taluk, Kancheepuram District 600 044          12
# University Departments of Anna University, Chennai - MIT Campus, Chrompet, Tambaram Taluk, Chengalpattu District 600 044          12
# Annamalai University Faculty of Engineering and Technology,Annamalai nagar,Cuddalore                                              12
# UNIVERSITY COLLEGE OF ENGINEERING, VILLUPURAM,VILLUPURAM (POST) , KAKUPPAM (VILLAGE),VILLUPURAM DIST, PIN - 605103.               10
# UNIVERSITY COLLEGE OF ENGINEERING, TINDIVANAM,IYYANTHOPE (POST) , MELPAKKAM (VILLAGE),VILLUPURAM DIST, PIN - 604001.              10
# UNIVERSITY COLLEGE OF ENGINEERING, ARNI,ARNI TO DEVIKAPURAM ROAD, THATCHUR, ARNI,THIRUVANNAMALAI DIST, PIN - 632326.              10
# University College of Engineering, Villupuram, Kakuppam, Villupuram District 605103                                               10
# UNIVERSITY COLLEGE OF ENGINEERING, KANCHIPURAM,NH-4, CHENNAI BANGALORE HIGHWAY, PONNERIKKARAI,KANCHEEPURAM DIST, PIN - 631552.     6
# University College of Engineering, Tindivanam, Melpakkam, Tindivanam, Villupuram District 604001                                   6
# Name: College_Name, dtype: int64

# %%
df_tmp.head()
# Out:
#     College Code                                       College_Name  \
# 0              1  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 32             4  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 33             4  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 34             4  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# 35             4  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
#
#    Branch Code                            Branch Name      OC      BC     BCM  \
# 0           AI  Agricultural and Irrigation Engg.(SS)  196.25  195.25  193.25
# 32          CM         Computer Science and Engg.(SS)  198.50  198.33  197.50
# 33          CS             Computer Science and Engg.  198.75  198.50  198.00
# 34          EC             Electronics and Comm Engg.  199.25  199.00  198.00
# 35          EI           Electronics and Instru Engg.  198.25  198.00  197.75
#
#        MBC      SC     SCA      ST  tYear
# 0   194.25  188.75  185.75  175.25   2017
# 32  197.00  192.00  186.00     NaN   2017
# 33  197.75  195.00  197.50  192.25   2017
# 34  198.25  196.50  196.25  188.25   2017
# 35  197.25  192.75  190.75  176.50   2017

# %%
len(df_tmp)
# Out:
# 240

# %%
#EDA

# %%
df_tmp.OC.sort_values()
# Out:
# 237     80.00
# 231     80.00
# 168     81.50
# 228     81.50
# 171     82.50
#         ...
# 6      199.25
# 65     199.33
# 64     199.50
# 4      199.75
# 5      200.00
# Name: OC, Length: 240, dtype: float64

# %%
df_tmp.ST.sort_values()
# Out:
# 166     91.00
# 113     94.00
# 108     97.50
# 172    103.00
# 117    109.25
#         ...
# 202       NaN
# 203       NaN
# 206       NaN
# 208       NaN
# 239       NaN
# Name: ST, Length: 240, dtype: float64

# %%
#machine learning model

# %%
len(df_tmp)
# Out:
# 240

# %% [markdown]
# # Modelling

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_jobs=-1,random_state=42)

model.fit(df_tmp.drop("OC", axis=1), df_tmp["OC"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 30 in 5
#       <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.ensemble import RandomForestRegressor
#       <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> model = RandomForestRegressor(n_jobs=-1,random_state=42)
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> model.fit(df_tmp.drop("OC", axis=1), df_tmp["OC"])
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHENNAI - CEG CAMPUS,SARDAR PATEL ROAD, GUINDY,CHENNAI DIST, PIN - 600025.'

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   College Code  240 non-null    int64
#  1   College_Name  240 non-null    object
#  2   Branch Code   240 non-null    object
#  3   Branch Name   240 non-null    object
#  4   OC            240 non-null    float64
#  5   BC            227 non-null    float64
#  6   BCM           218 non-null    float64
#  7   MBC           228 non-null    float64
#  8   SC            228 non-null    float64
#  9   SCA           203 non-null    float64
#  10  ST            118 non-null    float64
#  11  tYear         240 non-null    int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 24.4+ KB

# %%
df_tmp["College_Name"].dtype
# Out:
# dtype('O')

# %%
df.isna().sum()
# Out:
# Year              0
# College Code      0
# College_Name      0
# Branch Code       0
# Branch Name       0
# OC                0
# BC               13
# BCM              22
# MBC              12
# SC               12
# SCA              37
# ST              122
# dtype: int64

# %%
#model driven EDA

# %% [markdown]
# # Convert string to categories

# %%
df_tmp.head().T
# Out:
#                                                              0   \
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  AI
# Branch Name               Agricultural and Irrigation Engg.(SS)
# OC                                                       196.25
# BC                                                       195.25
# BCM                                                      193.25
# MBC                                                      194.25
# SC                                                       188.75
# SCA                                                      185.75
# ST                                                       175.25
# tYear                                                      2017
#
#                                                              32  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CM
# Branch Name                      Computer Science and Engg.(SS)
# OC                                                        198.5
# BC                                                       198.33
# BCM                                                       197.5
# MBC                                                       197.0
# SC                                                        192.0
# SCA                                                       186.0
# ST                                                          NaN
# tYear                                                      2017
#
#                                                              33  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CS
# Branch Name                          Computer Science and Engg.
# OC                                                       198.75
# BC                                                        198.5
# BCM                                                       198.0
# MBC                                                      197.75
# SC                                                        195.0
# SCA                                                       197.5
# ST                                                       192.25
# tYear                                                      2017
#
#                                                              34  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EC
# Branch Name                          Electronics and Comm Engg.
# OC                                                       199.25
# BC                                                        199.0
# BCM                                                       198.0
# MBC                                                      198.25
# SC                                                        196.5
# SCA                                                      196.25
# ST                                                       188.25
# tYear                                                      2017
#
#                                                              35
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EI
# Branch Name                        Electronics and Instru Engg.
# OC                                                       198.25
# BC                                                        198.0
# BCM                                                      197.75
# MBC                                                      197.25
# SC                                                       192.75
# SCA                                                      190.75
# ST                                                        176.5
# tYear                                                      2017

# %%
pd.api.types.is_string_dtype(df_tmp["College_Name"])
# Out:
# False

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        print(label)

# %%
#category- Finite list of text values

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()    #Set the Categorical to be ordered.

# %%
df_tmp.info()  #changed from obj to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   College Code             240 non-null    int64
#  1   College_Name             240 non-null    int64
#  2   Branch Code              240 non-null    int64
#  3   Branch Name              240 non-null    int64
#  4   OC                       240 non-null    float64
#  5   BC                       240 non-null    float64
#  6   BCM                      240 non-null    float64
#  7   MBC                      240 non-null    float64
#  8   SC                       240 non-null    float64
#  9   SCA                      240 non-null    float64
#  10  ST                       240 non-null    float64
#  11  tYear                    240 non-null    int64
#  12  BC_is_missing            240 non-null    bool
#  13  BCM_is_missing           240 non-null    bool
#  14  MBC_is_missing           240 non-null    bool
#  15  SC_is_missing            240 non-null    bool
#  16  SCA_is_missing           240 non-null    bool
#  17  ST_is_missing            240 non-null    bool
#  18  College_Name_is_missing  240 non-null    bool
#  19  Branch Code_is_missing   240 non-null    bool
#  20  Branch Name_is_missing   240 non-null    bool
# dtypes: bool(9), float64(7), int64(5)
# memory usage: 24.7 KB

# %%
df_tmp.College_Name.cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 42 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> df_tmp.College_Name.cat.categories
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\arrays\categorical.py:2717, in CategoricalAccessor.__init__(self, data)
#    2716 def __init__(self, data):
# -> 2717     self._validate(data)
#    2718     self._parent = data.values
#    2719     self._index = data.index
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\arrays\categorical.py:2726, in CategoricalAccessor._validate(data)
#    2723 @staticmethod
#    2724 def _validate(data):
#    2725     if not is_categorical_dtype(data.dtype):
# -> 2726         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
df_tmp.College_Name.cat.codes
# Out:
# 0       7
# 32      8
# 33      8
# 34      8
# 35      8
#        ..
# 204    11
# 205    11
# 206    11
# 208    13
# 239     9
# Length: 240, dtype: int8

# %% [markdown]
# df_tmp.isnull().sum()/len(df_tmp)

# %% [markdown]
# # Save preprocessed data

# %%
df_tmp.to_csv("data/train_tmp.csv",index=False)

# %%
df_tmp = pd.read_csv("data/train_tmp.csv",low_memory=False)
df_tmp.head().T
# Out:
#                                                               0  \
# College Code                                                  1
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  AI
# Branch Name               Agricultural and Irrigation Engg.(SS)
# OC                                                       196.25
# BC                                                       195.25
# BCM                                                      193.25
# MBC                                                      194.25
# SC                                                       188.75
# SCA                                                      185.75
# ST                                                       175.25
# tYear                                                      2017
#
#                                                               1  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CM
# Branch Name                      Computer Science and Engg.(SS)
# OC                                                        198.5
# BC                                                       198.33
# BCM                                                       197.5
# MBC                                                       197.0
# SC                                                        192.0
# SCA                                                       186.0
# ST                                                          NaN
# tYear                                                      2017
#
#                                                               2  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  CS
# Branch Name                          Computer Science and Engg.
# OC                                                       198.75
# BC                                                        198.5
# BCM                                                       198.0
# MBC                                                      197.75
# SC                                                        195.0
# SCA                                                       197.5
# ST                                                       192.25
# tYear                                                      2017
#
#                                                               3  \
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EC
# Branch Name                          Electronics and Comm Engg.
# OC                                                       199.25
# BC                                                        199.0
# BCM                                                       198.0
# MBC                                                      198.25
# SC                                                        196.5
# SCA                                                      196.25
# ST                                                       188.25
# tYear                                                      2017
#
#                                                               4
# College Code                                                  4
# College_Name  UNIVERSITY DEPARTMENTS OF ANNA UNIVERSITY, CHE...
# Branch Code                                                  EI
# Branch Name                        Electronics and Instru Engg.
# OC                                                       198.25
# BC                                                        198.0
# BCM                                                      197.75
# MBC                                                      197.25
# SC                                                       192.75
# SCA                                                      190.75
# ST                                                        176.5
# tYear                                                      2017

# %%
df_tmp.isna().sum()
# Out:
# College Code      0
# College_Name      0
# Branch Code       0
# Branch Name       0
# OC                0
# BC               13
# BCM              22
# MBC              12
# SC               12
# SCA              37
# ST              122
# tYear             0
# dtype: int64

# %% [markdown]
# # Fill missing values
# Fill numerical missing values first

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# College Code
# OC
# BC
# BCM
# MBC
# SC
# SCA
# ST
# tYear

# %%
df_tmp.BCM
# Out:
# 0      193.25
# 1      197.50
# 2      198.00
# 3      198.00
# 4      197.75
#         ...
# 235    162.50
# 236    174.50
# 237    175.50
# 238    189.50
# 239     86.00
# Name: BCM, Length: 240, dtype: float64

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# BC
# BCM
# MBC
# SC
# SCA
# ST

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            df_tmp[label+"_is_missing"] = pd.isnull(content)
            df_tmp[label] = content.fillna(content.median())

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)

# %% [markdown]
# df_tmp.MBCDNC_is_missing.value_counts()

# %% [markdown]
# df_tmp.ST_is_missing.value_counts()

# %%
df_tmp.isna().sum()
# Out:
# College Code      0
# College_Name      0
# Branch Code       0
# Branch Name       0
# OC                0
# BC                0
# BCM               0
# MBC               0
# SC                0
# SCA               0
# ST                0
# tYear             0
# BC_is_missing     0
# BCM_is_missing    0
# MBC_is_missing    0
# SC_is_missing     0
# SCA_is_missing    0
# ST_is_missing     0
# dtype: int64

# %%
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# College_Name
# Branch Code
# Branch Name

# %%
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_tmp[label+"_is_missing"] = pd.isnull(content)
        df_tmp[label] = pd.Categorical(content).codes+1

# %%
pd.Categorical(df_tmp["College_Name"]).codes+1
# Out:
# array([ 8,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9,  6,  6,  6,  6,  5,  5,
#         5,  5,  5,  3,  3,  3,  3,  3,  4,  4,  4,  9,  9,  6,  7,  9,  8,
#         8,  8,  8,  8,  8,  8,  8,  8,  8,  8,  8,  8,  8,  7,  8,  8,  7,
#         7,  7,  7,  7,  7,  8,  7,  7,  7,  9,  9,  9,  6,  9,  9,  9,  9,
#         9,  9,  9,  6,  9,  6,  5,  6,  5,  5,  5,  5,  3,  3,  3,  3,  3,
#         4,  4,  6,  9,  4,  7,  8,  8,  8,  8,  8,  8,  8,  9,  8,  8,  8,
#         8,  8,  8,  8,  8,  8,  7,  7,  7,  7,  7,  7,  7,  7,  7,  8,  8,
#         7,  2,  2,  2,  2, 15, 15, 15, 15, 15, 15, 15, 15,  2, 10,  2,  2,
#         2,  2,  2, 11, 11, 11, 11, 11, 10, 10, 15,  2, 15,  2, 15, 13, 13,
#        13, 13, 13, 13, 13, 15, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12,
#        12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 14,  1,  1,  1, 14, 14, 14,
#        14, 14, 14, 14, 14,  1, 10,  1,  1,  1,  1,  1,  1,  1, 11, 11, 11,
#        11, 11, 14,  1, 14, 13, 12, 10, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,
#        14, 10], dtype=int8)

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   College Code             240 non-null    int64
#  1   College_Name             240 non-null    int8
#  2   Branch Code              240 non-null    int8
#  3   Branch Name              240 non-null    int8
#  4   OC                       240 non-null    float64
#  5   BC                       240 non-null    float64
#  6   BCM                      240 non-null    float64
#  7   MBC                      240 non-null    float64
#  8   SC                       240 non-null    float64
#  9   SCA                      240 non-null    float64
#  10  ST                       240 non-null    float64
#  11  tYear                    240 non-null    int64
#  12  BC_is_missing            240 non-null    bool
#  13  BCM_is_missing           240 non-null    bool
#  14  MBC_is_missing           240 non-null    bool
#  15  SC_is_missing            240 non-null    bool
#  16  SCA_is_missing           240 non-null    bool
#  17  ST_is_missing            240 non-null    bool
#  18  College_Name_is_missing  240 non-null    bool
#  19  Branch Code_is_missing   240 non-null    bool
#  20  Branch Name_is_missing   240 non-null    bool
# dtypes: bool(9), float64(7), int64(2), int8(3)
# memory usage: 19.8 KB

# %%
df_tmp.to_csv("data/train_tmp.csv",index=False)

# %%
df_tmp = pd.read_csv("data/train_tmp.csv",low_memory=False)
df_tmp.head().T
# Out:
#                               0       1       2       3       4
# College Code                  1       4       4       4       4
# College_Name                  8       9       9       9       9
# Branch Code                   2      12      14      16      18
# Branch Name                   7      30      29      43      47
# OC                       196.25   198.5  198.75  199.25  198.25
# BC                       195.25  198.33   198.5   199.0   198.0
# BCM                      193.25   197.5   198.0   198.0  197.75
# MBC                      194.25   197.0  197.75  198.25  197.25
# SC                       188.75   192.0   195.0   196.5  192.75
# SCA                      185.75   186.0   197.5  196.25  190.75
# ST                       175.25   167.0  192.25  188.25   176.5
# tYear                      2017    2017    2017    2017    2017
# BC_is_missing             False   False   False   False   False
# BCM_is_missing            False   False   False   False   False
# MBC_is_missing            False   False   False   False   False
# SC_is_missing             False   False   False   False   False
# SCA_is_missing            False   False   False   False   False
# ST_is_missing             False    True   False   False   False
# College_Name_is_missing   False   False   False   False   False
# Branch Code_is_missing    False   False   False   False   False
# Branch Name_is_missing    False   False   False   False   False

# %%
df_tmp.head().T
# Out:
#                               0       1       2       3       4
# College Code                  1       4       4       4       4
# College_Name                  8       9       9       9       9
# Branch Code                   2      12      14      16      18
# Branch Name                   7      30      29      43      47
# OC                       196.25   198.5  198.75  199.25  198.25
# BC                       195.25  198.33   198.5   199.0   198.0
# BCM                      193.25   197.5   198.0   198.0  197.75
# MBC                      194.25   197.0  197.75  198.25  197.25
# SC                       188.75   192.0   195.0   196.5  192.75
# SCA                      185.75   186.0   197.5  196.25  190.75
# ST                       175.25   167.0  192.25  188.25   176.5
# tYear                      2017    2017    2017    2017    2017
# BC_is_missing             False   False   False   False   False
# BCM_is_missing            False   False   False   False   False
# MBC_is_missing            False   False   False   False   False
# SC_is_missing             False   False   False   False   False
# SCA_is_missing            False   False   False   False   False
# ST_is_missing             False    True   False   False   False
# College_Name_is_missing   False   False   False   False   False
# Branch Code_is_missing    False   False   False   False   False
# Branch Name_is_missing    False   False   False   False   False

# %%
df_tmp.to_csv("data/train_tmp.csv",index=False)

# %%
df_tmp = pd.read_csv("data/train_tmp.csv",low_memory=False)
df_tmp.head().T
# Out:
#                               0       1       2       3       4
# College Code                  1       4       4       4       4
# College_Name                  8       9       9       9       9
# Branch Code                   2      12      14      16      18
# Branch Name                   7      30      29      43      47
# OC                       196.25   198.5  198.75  199.25  198.25
# BC                       195.25  198.33   198.5   199.0   198.0
# BCM                      193.25   197.5   198.0   198.0  197.75
# MBC                      194.25   197.0  197.75  198.25  197.25
# SC                       188.75   192.0   195.0   196.5  192.75
# SCA                      185.75   186.0   197.5  196.25  190.75
# ST                       175.25   167.0  192.25  188.25   176.5
# tYear                      2017    2017    2017    2017    2017
# BC_is_missing             False   False   False   False   False
# BCM_is_missing            False   False   False   False   False
# MBC_is_missing            False   False   False   False   False
# SC_is_missing             False   False   False   False   False
# SCA_is_missing            False   False   False   False   False
# ST_is_missing             False    True   False   False   False
# College_Name_is_missing   False   False   False   False   False
# Branch Code_is_missing    False   False   False   False   False
# Branch Name_is_missing    False   False   False   False   False

# %%
df_tmp.isna().sum()
# Out:
# College Code               0
# College_Name               0
# Branch Code                0
# Branch Name                0
# OC                         0
# BC                         0
# BCM                        0
# MBC                        0
# SC                         0
# SCA                        0
# ST                         0
# tYear                      0
# BC_is_missing              0
# BCM_is_missing             0
# MBC_is_missing             0
# SC_is_missing              0
# SCA_is_missing             0
# ST_is_missing              0
# College_Name_is_missing    0
# Branch Code_is_missing     0
# Branch Name_is_missing     0
# dtype: int64

# %%
df_tmp.head()
# Out:
#    College Code  College_Name  Branch Code  Branch Name      OC      BC  \
# 0             1             8            2            7  196.25  195.25
# 1             4             9           12           30  198.50  198.33
# 2             4             9           14           29  198.75  198.50
# 3             4             9           16           43  199.25  199.00
# 4             4             9           18           47  198.25  198.00
#
#       BCM     MBC      SC     SCA  ...  tYear  BC_is_missing  BCM_is_missing  \
# 0  193.25  194.25  188.75  185.75  ...   2017          False           False
# 1  197.50  197.00  192.00  186.00  ...   2017          False           False
# 2  198.00  197.75  195.00  197.50  ...   2017          False           False
# 3  198.00  198.25  196.50  196.25  ...   2017          False           False
# 4  197.75  197.25  192.75  190.75  ...   2017          False           False
#
#    MBC_is_missing  SC_is_missing  SCA_is_missing  ST_is_missing  \
# 0           False          False           False          False
# 1           False          False           False           True
# 2           False          False           False          False
# 3           False          False           False          False
# 4           False          False           False          False
#
#    College_Name_is_missing  Branch Code_is_missing  Branch Name_is_missing
# 0                    False                   False                   False
# 1                    False                   False                   False
# 2                    False                   False                   False
# 3                    False                   False                   False
# 4                    False                   False                   False
#
# [5 rows x 21 columns]

# %%
len(df_tmp)
# Out:
# 240

# %%
# %%time
# Instantiate model
model = RandomForestRegressor(n_jobs=-1, random_state=42)

# Fit the model
model.fit(df_tmp.drop("OC", axis=1), df_tmp["OC"])
# Out:
# CPU times: total: 438 ms
# Wall time: 307 ms
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# Score the model
model.score(df_tmp.drop("OC", axis=1), df_tmp["OC"])
# Out:
# 0.9945104742162915

# %% [markdown]
# # Splitting data into train/validation sets

# %%
df_tmp.tYear
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 235    2020
# 236    2020
# 237    2020
# 238    2020
# 239    2020
# Name: tYear, Length: 240, dtype: int64

# %%
df_tmp.tYear.value_counts()
# Out:
# 2017    60
# 2018    60
# 2019    60
# 2020    60
# Name: tYear, dtype: int64

# %%
df_val = df_tmp[df_tmp.tYear == 2017]
df_train = df_tmp[df_tmp.tYear != 2017]

len(df_val), len(df_train)
# Out:
# (60, 180)

# %%
X_train, y_train = df_train.drop("OC", axis=1), df_train.OC
X_valid, y_valid = df_val.drop("OC", axis=1), df_val.OC

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((180, 20), (180,), (60, 20), (60,))

# %%
y_train
# Out:
# 60     196.50
# 61     193.50
# 62     195.33
# 63     175.00
# 64     190.00
#         ...
# 235    167.50
# 236    182.50
# 237    177.50
# 238    191.50
# 239    118.00
# Name: OC, Length: 180, dtype: float64

# %% [markdown]
# # Testing our model on a subset (to tune the hyperparameters)

# %%
# %%time
 model = RandomForestRegressor(n_jobs=-1, 
                              random_state=42)

 model.fit(X_train, y_train)
# Out:
# CPU times: total: 344 ms
# Wall time: 278 ms
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
len(X_train)
# Out:
# 180

# %%
model = RandomForestRegressor(n_jobs=-1,
                              random_state=42,
                              max_samples=100)

# %%
# %%time
# Cutting down on the max number of samples each estimator can see improves training time
model.fit(X_train, y_train)
# Out:
# CPU times: total: 406 ms
# Wall time: 243 ms
# RandomForestRegressor(max_samples=100, n_jobs=-1, random_state=42)

# %% [markdown]
# (X_train.shape[0] * 100) / 1000000

# %% [markdown]
# 10000 * 100

# %%
show_scores(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 85 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y150sZmlsZQ%3D%3D?line=0'>1</a> show_scores(model)
#
# NameError: name 'show_scores' is not defined

# %% [markdown]
# # Make predictions on test data

# %%
df_test = pd.read_csv("data/2021 - Sheet1.csv",
                      low_memory=False,
                      parse_dates=["Year"])

df_test.head()
# Out:
#         Year  College Code                                       College_Name  \
# 0 2021-01-01             1  University Departments of Anna University, Che...
# 1 2021-01-01             1  University Departments of Anna University, Che...
# 2 2021-01-01             1  University Departments of Anna University, Che...
# 3 2021-01-01             1  University Departments of Anna University, Che...
# 4 2021-01-01             1  University Departments of Anna University, Che...
#
#   Branch Code                                Branch Name          BC      BCM  \
# 0          BY               BIO MEDICAL ENGINEERING (SS)  194.000000  193.500
# 1          CE                          CIVIL ENGINEERING  192.685000  190.500
# 2          CM      COMPUTER SCIENCE AND ENGINEERING (SS)  197.666667  196.375
# 3          CS           COMPUTER SCIENCE AND ENGINEERING  198.120000  197.020
# 4          EC  ELECTRONICS AND COMMUNICATION ENGINEERING  197.333333  196.000
#
#        MBC      SC      SCA       ST
# 0  194.775  189.00  182.500  181.000
# 1  193.330  190.00  182.000  174.635
# 2  197.500  193.00  192.060  190.815
# 3  198.625  196.50  193.935  192.165
# 4  197.130  194.35  192.000  192.500

# %%
test_preds = model.predict(df_test)
# Out:
# c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Year
# Feature names seen at fit time, yet now missing:
# - BCM_is_missing
# - BC_is_missing
# - Branch Code_is_missing
# - Branch Name_is_missing
# - College_Name_is_missing
# - ...
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 88 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> test_preds = model.predict(df_test)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\ensemble\_forest.py:991, in ForestRegressor.predict(self, X)
#     989 check_is_fitted(self)
#     990 # Check data
# --> 991 X = self._validate_X_predict(X)
#     993 # Assign chunk of trees to jobs
#     994 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\ensemble\_forest.py:605, in BaseForest._validate_X_predict(self, X)
#     602 """
#     603 Validate X whenever one tries to predict, apply, predict_proba."""
#     604 check_is_fitted(self)
# --> 605 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     606 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     607     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# TypeError: float() argument must be a string or a real number, not 'Timestamp'

# %% [markdown]
# # Preprocessing the data (getting the test dataset in the same format as our training dataset)

# %%
def preprocess_data(df):
    """
    Performs transformations on df and returns transformed df.
    """
    df["tYear"] = df.Year.dt.year
    #df_tmp["Year"] = df_tmp.Year.dt.year
    
    df.drop("Year", axis=1, inplace=True)
    
    
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                
                df[label+"_is_missing"] = pd.isnull(content)
                
                df[label] = content.fillna(content.median())
    
        
        if not pd.api.types.is_numeric_dtype(content):
            df[label+"_is_missing"] = pd.isnull(content)
           
            df[label] = pd.Categorical(content).codes+1
    
    return df

# %%
df_test = preprocess_data(df_test)
df_test.head()
# Out:
#    College Code  College_Name  Branch Code  Branch Name          BC      BCM  \
# 0             1             5            5            4  194.000000  193.500
# 1             1             5            6            9  192.685000  190.500
# 2             1             5           10           14  197.666667  196.375
# 3             1             5           12           11  198.120000  197.020
# 4             1             5           14           16  197.333333  196.000
#
#        MBC      SC      SCA       ST  tYear  College_Name_is_missing  \
# 0  194.775  189.00  182.500  181.000   2021                    False
# 1  193.330  190.00  182.000  174.635   2021                    False
# 2  197.500  193.00  192.060  190.815   2021                    False
# 3  198.625  196.50  193.935  192.165   2021                    False
# 4  197.130  194.35  192.000  192.500   2021                    False
#
#    Branch Code_is_missing  Branch Name_is_missing  BC_is_missing  \
# 0                   False                   False          False
# 1                   False                   False          False
# 2                   False                   False          False
# 3                   False                   False          False
# 4                   False                   False          False
#
#    BCM_is_missing  MBC_is_missing  SC_is_missing  SCA_is_missing  \
# 0           False           False          False           False
# 1           False           False          False           False
# 2           False           False          False           False
# 3           False           False          False           False
# 4           False           False          False           False
#
#    ST_is_missing
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
test_preds =model.predict(df_test)  #Python predict() function enables us to predict the labels of the data values on the basis of the trained model
# Out:
# c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
X_train.head()
# Out:
#     College Code  College_Name  Branch Code  Branch Name      BC     BCM  \
# 60             4             9           31           72  196.25  194.00
# 61             4             9           37           87  192.25  189.75
# 62             4             9            6            4  194.25  191.75
# 63          1013             6           14           20  161.75  159.25
# 64             4             9           39           95  188.00  185.25
#
#        MBC      SC     SCA      ST  tYear  BC_is_missing  BCM_is_missing  \
# 60  195.00  190.00  182.75  168.75   2018          False           False
# 61  189.75  178.00  169.50  119.75   2018          False           False
# 62  193.00  182.25  179.00  171.25   2018          False           False
# 63  163.50  143.50  161.75  118.00   2018          False           False
# 64  185.50  172.00  146.75  141.75   2018          False           False
#
#     MBC_is_missing  SC_is_missing  SCA_is_missing  ST_is_missing  \
# 60           False          False           False          False
# 61           False          False           False          False
# 62           False          False           False          False
# 63           False          False            True          False
# 64           False          False           False          False
#
#     College_Name_is_missing  Branch Code_is_missing  Branch Name_is_missing
# 60                    False                   False                   False
# 61                    False                   False                   False
# 62                    False                   False                   False
# 63                    False                   False                   False
# 64                    False                   False                   False

# %%
set(X_train.columns) - set(df_test.columns)
# Out:
# set()

# %% [markdown]
# df_test["set()"] = False
# df_test.head()

# %%
test_preds = model.predict(df_test)
# Out:
# c:\Users\indhu\OneDrive\Desktop\tnea-proj\env\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# test_preds = ideal_model.predict(df_test)

# %% [markdown]
# df_test["set()"] = False
# df_test["Branch Code_is_missing"] = False
# df_test["Branch Name_is_missing"] = False
# df_test["College_Name_is_missing"] = False
# df_test.head()

# %%
test_preds
# Out:
# array([195.8397, 195.393 , 198.1266, 198.6843, 198.0357, 196.655 ,
#        197.2208, 194.7329, 193.881 , 196.915 , 192.7725, 195.5131,
#        191.48  , 192.2992, 191.5175, 186.7075, 188.1025, 186.94  ,
#        194.5974, 192.5851, 186.87  , 192.1043, 194.4948, 194.7131,
#        187.    , 191.5467, 189.24  , 187.8275, 195.7263, 191.7425,
#        196.9225, 197.5141, 195.6308, 195.7447, 196.5375, 196.6525,
#        195.1655, 191.7575, 188.6525, 155.85  , 158.355 , 156.6375,
#        158.345 , 149.0325, 151.625 , 155.8525, 155.6525, 159.3175,
#        154.145 , 153.2675, 143.075 , 150.5725, 157.0875, 154.015 ,
#        156.4675, 124.72  , 155.825 , 154.9075, 158.06  , 154.5525])

# %%
df_preds = pd.DataFrame()
df_preds["College_Name"] = df_test["College_Name"]
df_preds["OC"] = test_preds
df_preds
# Out:
#     College_Name        OC
# 0              5  195.8397
# 1              5  195.3930
# 2              5  198.1266
# 3              5  198.6843
# 4              5  198.0357
# 5              5  196.6550
# 6              5  197.2208
# 7              5  194.7329
# 8              5  193.8810
# 9              5  196.9150
# 10             5  192.7725
# 11             5  195.5131
# 12             5  191.4800
# 13             5  192.2992
# 14             5  191.5175
# 15             5  186.7075
# 16             5  188.1025
# 17             4  186.9400
# 18             4  194.5974
# 19             4  192.5851
# 20             4  186.8700
# 21             4  192.1043
# 22             4  194.4948
# 23             4  194.7131
# 24             4  187.0000
# 25             4  191.5467
# 26             4  189.2400
# 27             4  187.8275
# 28             6  195.7263
# 29             6  191.7425
# 30             6  196.9225
# 31             6  197.5141
# 32             6  195.6308
# 33             6  195.7447
# 34             6  196.5375
# 35             6  196.6525
# 36             6  195.1655
# 37             6  191.7575
# 38             6  188.6525
# 39             1  155.8500
# 40             1  158.3550
# 41             1  156.6375
# 42             1  158.3450
# 43             1  149.0325
# 44             1  151.6250
# 45             1  155.8525
# 46             1  155.6525
# 47             1  159.3175
# 48             1  154.1450
# 49             1  153.2675
# 50             1  143.0750
# 51             3  150.5725
# 52             3  157.0875
# 53             3  154.0150
# 54             3  156.4675
# 55             3  124.7200
# 56             2  155.8250
# 57             2  154.9075
# 58             2  158.0600
# 59             2  154.5525

# %%
df_preds.to_csv("data/predictions.csv", index=False)

# %%
dff = pd.read_csv("data/predictions.csv",low_memory=False)

# %%
fig, ax = plt.subplots()
ax.scatter(dff["College_Name"][:1000], dff["OC"][:1000])
plt.xlabel("College_Name")
plt.ylabel("Cutoff mark")
plt.title("Predicted Cutoff Marks of OC category 2021")
# Out:
# Text(0.5, 1.0, 'Predicted Cutoff Marks of OC category 2021')

# %%
model.save_model('rf.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 104 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y204sZmlsZQ%3D%3D?line=0'>1</a> model.save_model('rf.json')
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'save_model'

# %%
import json
model_param= {}
model_param['coef']=list(model.coef_)
model_param['intercept']= model.intercept_.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Github desktopunga\TNEA_PREDICTOR_\end-to-end-tnea-cutoff-prediction final .ipynb Cell 105 in 3
#       <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y205sZmlsZQ%3D%3D?line=0'>1</a> import json
#       <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y205sZmlsZQ%3D%3D?line=1'>2</a> model_param= {}
# ----> <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y205sZmlsZQ%3D%3D?line=2'>3</a> model_param['coef']=list(model.coef_)
#       <a href='vscode-notebook-cell:/d%3A/Github%20desktopunga/TNEA_PREDICTOR_/end-to-end-tnea-cutoff-prediction%20final%20.ipynb#Y205sZmlsZQ%3D%3D?line=3'>4</a> model_param['intercept']= model.intercept_.tolist()
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'coef_'

# %%
json_txt=json.dumps(model_param,indent=4)
with open('model_param.txt','w') as file:
    file.write(json_txt)

# %%
with open('model_param.txt','r') as file:
    dict_=json.load(file)
